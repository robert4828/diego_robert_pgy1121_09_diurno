# %%
prueba = 0

lista_nombre = []
lista_nif = []
lista_edad = []


def grabar_datos (nif,nombre,edad):
  if grabar_datos ==  1:
    print=int(input("ingrese su nombre:"))
    lista_nombre
  if grabar_datos == 2:
    print=int(input("inrgese su nif: "))
    lista_nif.append
  if grabar_datos == 3:
    print=int(input("ingrese su edad: "))
    lista_edad.append


def imprimir_certificado ():
  certificado = int(input("que certificado desea imprimir?: "))
  if certificado == 1:
    print("certificado de nacimiento")
  elif certificado == 2:
    print("estado conyugal")
  elif certificado == 3:
    print("perteneciente a la union europea")


def validador_nif (nif):
  if len(nif) == 12:
    return False
def validador_nombre (nombre):
  if len(nombre) == 8:
    return False
def validador_edad (edad):
  if len(edad) >= 0:


def menu ():
  print("opcion 1: grabar datos")
  print("opcion 2: buscar persona")
  print("opcion 3: imprimir certificado")
  print("opcion 4: salir de menu")

  while prueba == 0:
    op = int(input("que opcion desea: "))
    if op == 1:
      print=int(input("ingrese su NIF: "))
      print("ingrese su nombre: ")
      print("ingrese su edad: ")
    if op == 2:
      print=int(input("ingrese nif de la persona: "))
    else:
      print("el nif ingresado debe ser minimo 8 caracteres")
    if op == 3:
      print("que certificado desea imprimir? : ")
    while certificado == 0:
      print("certificado de nacimiento")
      print("estado conyugal")
      print("perteneciente a la union europe")
    if op == 4:
      prueba = 0
      print("usted a elegido salir de menu")
